# %%
import pandas as pd
import numpy as np

# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq
import ssl
# This restores the same behavior as before.
context = ssl._create_unverified_context()
my_url="https://www.flipkart.com/clothing-and-accessories/dresses-and-gown/dress/women-dress/pr?sid=clo,odx,maj,jhy&otracker=categorytree&otracker=nmenu_sub_Women_0_Dresses"
uClient = uReq(my_url, context=context)
page_html = uClient.read()
uClient.close()

# %%
page_soup = soup(page_html, "html.parser")
page_soup
# Out:
# <!DOCTYPE html>
# ...

# %%
containers = page_soup.findAll("div", { "class": "DOjaWF gdgoEp"})
print(len(containers))
print(soup.prettify(containers[0]))
# Out:
# 1
# <div class="DOjaWF gdgoEp" style="flex-grow:1;overflow:auto">
#  <div class="DOjaWF YJG4Cf col-12-12" style="background-color:#ffffff;align-items:flex-end">
#   <div class="cPHDOP" style="flex-grow:1;overflow:auto">
#    <div class="WOvzF4">
#     <div class="_7dPnhA">
#      <div class="r2CdBx">
#       <a class="R0cyWM" href="/">
#        Home
#       </a>
#       <svg class="sfneHK" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#        <path class="wMLTcO" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#        </path>
#       </svg>
#      </div>
#      <div class="r2CdBx">
#       <a class="R0cyWM" href="/clothing-and-accessories/pr?sid=clo&amp;marketplace=FLIPKART">
#        Clothing and Accessories
#       </a>
#       <svg class="sfneHK" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
# ...

# %%
prod_contents = containers[0]
prod_contents
# Out:
# <div class="DOjaWF gdgoEp" style="flex-grow:1;overflow:auto"><div class="DOjaWF YJG4Cf col-12-12" style="background-color:#ffffff;align-items:flex-end"><div class="cPHDOP" style="flex-grow:1;overflow:auto"><div class="WOvzF4"><div class="_7dPnhA"><div class="r2CdBx"><a class="R0cyWM" href="/">Home</a><svg class="sfneHK" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="wMLTcO" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><div class="r2CdBx"><a class="R0cyWM" href="/clothing-and-accessories/pr?sid=clo&amp;marketplace=FLIPKART">Clothing and Accessories</a><svg class="sfneHK" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="wMLTcO" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><div class="r2CdBx"><a class="R0cyWM" href="/clothing-and-accessories/dresses-and-gowns/pr?sid=clo,odx&amp;marketplace=FLIP
# ...

# %%
product_image = prod_contents.findAll("div", {"class": "wvIX4U"})
product_image[0].findAll("img", {"class":"_53J4C-"})[0]['src']
# Out:
# 'https://rukminim2.flixcart.com/image/612/612/xif0q/dress/k/1/0/xl-6084-sheetal-associates-original-imagm86ekphn94e2.jpeg?q=70'

# %%
product_name = prod_contents.findAll("div", {"class": "syl9yP"})
print(product_name[0].text)
# Out:
# Honky Tonky

# %%
price = prod_contents.findAll("div", {"class": "Nx9bqj"})
print(price[0].text)
# Out:
# ₹295

# %%
discount = prod_contents.findAll("div", {"class": "UkUFwK"})
print(discount[0].text)
# Out:
# 85% off

# %%
delivery = prod_contents.findAll("div", {"class": "yiggsN"})
print(delivery[0].text)
# Out:
# Free delivery

# %%
products_image = []
products_name = []
pricing = []
discount = []
delivery_status = []

for content in prod_contents:
    for product in content:
        # Let's scrape the product image
        image = product.findAll("div", {"class": "wvIX4U"})
        if len(image) == 0:
            products_image.append(np.nan)
        else:
            products_image.append(image[0].findAll("img",{"class":"_53J4C-"})[0]['src'])
        
        # Let's scrape the product name
        name = product.findAll("div", {"class": "syl9yP"})
        if len(name) == 0:
            products_name.append(np.nan)
        else:
            products_name.append(name[0].text)

        # scrape for price
        price = product.findAll("div", {"class": "Nx9bqj"})
        if len(price) == 0:
            pricing.append(np.nan)
        else:
            pricing.append(price[0].text)

        # Now let's have a look at its discount:
        discount_off = product.findAll("div", {"class": "UkUFwK"})
        if len(discount_off) == 0:
            discount.append(np.nan)
        else:
            discount.append(discount_off[0].text)

        
        # Now let's have a look at its free delivery:
        delivery = product.findAll("div", {"class": "yiggsN"})
        if len(delivery) == 0:
            delivery_status.append(np.nan)
        else:
            delivery_status.append(delivery[0].text)
           
print(len(products_image))
print(len(products_name))
print(len(pricing))
print(len(discount))
print(len(delivery_status))
# Out:
# 13
# 13
# 13
# 13
# 13

# %%
products_image = []
products_name = []
pricing = []
discount = []
delivery_status = []

my_url=["https://www.flipkart.com/clothing-and-accessories/dresses-and-gown/dress/women-dress/pr?sid=clo,odx,maj,jhy&otracker=categorytree&otracker=nmenu_sub_Women_0_Dresses",
        "https://www.flipkart.com/clothing-and-accessories/dresses-and-gown/dress/women-dress/pr?sid=clo%2Codx%2Cmaj%2Cjhy&otracker=categorytree&otracker=nmenu_sub_Women_0_Dresses&page=2",
        "https://www.flipkart.com/clothing-and-accessories/dresses-and-gown/dress/women-dress/pr?sid=clo%2Codx%2Cmaj%2Cjhy&otracker=categorytree&otracker=nmenu_sub_Women_0_Dresses&page=3",
        "https://www.flipkart.com/clothing-and-accessories/dresses-and-gown/dress/women-dress/pr?sid=clo%2Codx%2Cmaj%2Cjhy&otracker=categorytree&otracker=nmenu_sub_Women_0_Dresses&page=4",
        "https://www.flipkart.com/clothing-and-accessories/dresses-and-gown/dress/women-dress/pr?sid=clo%2Codx%2Cmaj%2Cjhy&otracker=categorytree&otracker=nmenu_sub_Women_0_Dresses&page=5",
        "https://www.flipkart.com/clothing-and-accessories/dresses-and-gown/dress/women-dress/pr?sid=clo%2Codx%2Cmaj%2Cjhy&otracker=categorytree&otracker=nmenu_sub_Women_0_Dresses&page=6",
        "https://www.flipkart.com/clothing-and-accessories/dresses-and-gown/dress/women-dress/pr?sid=clo%2Codx%2Cmaj%2Cjhy&otracker=categorytree&otracker=nmenu_sub_Women_0_Dresses&page=7",
        "https://www.flipkart.com/clothing-and-accessories/dresses-and-gown/dress/women-dress/pr?sid=clo%2Codx%2Cmaj%2Cjhy&otracker=categorytree&otracker=nmenu_sub_Women_0_Dresses&page=8",
        "https://www.flipkart.com/clothing-and-accessories/dresses-and-gown/dress/women-dress/pr?sid=clo%2Codx%2Cmaj%2Cjhy&otracker=categorytree&otracker=nmenu_sub_Women_0_Dresses&page=5",
        "https://www.flipkart.com/clothing-and-accessories/dresses-and-gown/dress/women-dress/pr?sid=clo%2Codx%2Cmaj%2Cjhy&otracker=categorytree&otracker=nmenu_sub_Women_0_Dresses&page=10",
       ]

for link in my_url:

    # This restores the same behavior as before.
    context = ssl._create_unverified_context()
    uClient = uReq(link, context=context)
    page_html = uClient.read()
    uClient.close()

    page_soup = soup(page_html, "html.parser")

    for content in prod_contents:
        for product in content:
            # Let's scrape the product image
            image = product.findAll("div", {"class": "wvIX4U"})
            if len(image) == 0:
                products_image.append(np.nan)
            else:
                products_image.append(image[0].findAll("img",{"class":"_53J4C-"})[0]['src'])
        
            # Let's scrape the product name
            name = product.findAll("div", {"class": "syl9yP"})
            if len(name) == 0:
                products_name.append(np.nan)
            else:
                products_name.append(name[0].text)

            # scrape for price
            price = product.findAll("div", {"class": "Nx9bqj"})
            if len(price) == 0:
                pricing.append(np.nan)
            else:
                pricing.append(price[0].text)

            # Now let's have a look at its discount:
            discount_off = product.findAll("div", {"class": "UkUFwK"})
            if len(discount_off) == 0:
                discount.append(np.nan)
            else:
                discount.append(discount_off[0].text)

        
            # Now let's have a look at its free delivery:
            delivery = product.findAll("div", {"class": "yiggsN"})
            if len(delivery) == 0:
                delivery_status.append(np.nan)
            else:
                delivery_status.append(delivery[0].text)
           
print(len(products_image))
print(len(products_name))
print(len(pricing))
print(len(discount))
print(len(delivery_status))
# Out:
# 130
# 130
# 130
# 130
# 130

# %%
df = pd.DataFrame({"Product Name":products_name, "Price":pricing, 
                   "Image":products_image, "Discount":discount, "Delivery":delivery_status})
df.to_csv("women_dress_data.csv")

laptop = pd.read_csv("women_dress_data.csv")
print(laptop.shape)
laptop.head()
# Out:
# (130, 6)
#    Unnamed: 0        Product Name Price  \
# 0           0                 NaN   NaN
# 1           1         Honky Tonky  ₹295
# 2           2  Sheetal Associates  ₹293
# 3           3       Tokyo Talkies  ₹464
# 4           4         Honky Tonky  ₹290
#
#                                                Image Discount       Delivery
# 0                                                NaN      NaN            NaN
# 1  https://rukminim2.flixcart.com/image/612/612/x...  85% off  Free delivery
# 2  https://rukminim2.flixcart.com/image/612/612/x...  78% off  Free delivery
# 3  https://rukminim2.flixcart.com/image/612/612/x...  76% off  Free delivery
# 4  https://rukminim2.flixcart.com/image/612/612/x...  78% off  Free delivery
