# %%
import pandas as pd
import numpy as np

# %%
import asyncio
import pandas as pd
from itertools import zip_longest
from playwright.async_api import async_playwright

async def scrape_jumia():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)  # Run in headless mode
        page = await browser.new_page()

        # Go to Jumia gaming laptops category
        await page.goto("https://www.jumia.com.ng/gaming-laptops/")

        # Wait for products to load
        await page.wait_for_selector(".name")

        # Extract product names
        product_names = await page.locator(".name").all_inner_texts()

        # Extract prices
        product_prices = await page.locator(".prc").all_inner_texts()

        # Extract ratings
        product_rating = await page.locator(".rev").all_inner_texts()

        # Extract image URLs
        product_images = await page.locator(".img").evaluate_all("elements => elements.map(e => e.getAttribute('data-src'))")

        # Debug: Print lengths of all lists
        print(f"Names: {len(product_names)}, Prices: {len(product_prices)}, Ratings: {len(product_rating)}, Images: {len(product_images)}")

        # Ensure all lists have the same length by filling missing values with "N/A"
        aligned_data = list(zip_longest(product_names, product_prices, product_rating, product_images, fillvalue="N/A"))

        # Print extracted data
        for name, price, rating, img in aligned_data:
            print(f"Product: {name} | Price: {price} | Rating: {rating} | Image: {img}")

        # Save to CSV
        df = pd.DataFrame(aligned_data, columns=["Product Name", "Price", "Rating", "Image URL"])
        df.to_csv("jumia_products.csv", index=False)
        print("Data saved to jumia_products.csv")

        await browser.close()

# Run the scraper
await scrape_jumia()  # Use await instead of asyncio.run() in Jupyter
# Out:
# Names: 40, Prices: 40, Ratings: 8, Images: 40
# Product: Lenovo Legion Pro 5 16IRX9 Gaming | Price: ₦ 4,000,000 | Rating: 4.4 out of 5
# (9) | Image: https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/65/7253293/1.jpg?2813
# Product: Hp 15 VICTUS GAMING, 12TH GEN INTEL CORE I5, 16GB RAM, 512GB SSD NVIDIA RTX 3050 (4GB) WINS 11 | Price: ₦ 1,340,000 | Rating: 3.8 out of 5
# (5) | Image: https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/87/9747762/1.jpg?4591
# Product: Anti Blue Ray Light Blocking Glasses For Computers / Phones | Price: ₦ 4,199 | Rating: 5 out of 5
# (2) | Image: https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/37/0368273/1.jpg?4891
# Product: Lenovo Legion 7i - 16.0" WQXGA Display - 32GB RAM / 1TB SSD - Nvidia GeForce RTX 4070 (8GB) - 14th Gen Core I9-14900HX - Windows 11 - Glacier White. | Price: ₦ 4,000,000 | Rating: 3.3 out of 5
# (4) | Image: https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/06/0633993/1.jpg?8509
# Product: Hp OMEN TRANSCEND 14 14TH GEN INTEL CORE ULTRA 9 UP TO 5.1GHz 32GB RAM 1TB SSD RTX 4070 (8GB) WINS 11 | Price: ₦ 3,999,999 | Rating: 5 out of 5
# (1) | Image: https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/22/9785383/1.jpg?6815
# Product: Hp Omen 16 Gaming 13th Gen Intel Core I7 16GB RAM/1TB SSD 16.1" Nvidia RTX 4050 6GB WINS 11 | Price: ₦ 2,500,000 | Rating: 5 out of 5
# (1) | Image: https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product
000 | Rating: N/A | Image: https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/67/6866762/1.jpg?5461
# Product: Hp Victus Gaming 16 13th Gen Intel Core I7 16GB RAM/1TB SSD RTX 3050 (6GB) Win 11 | Price: ₦ 2,100,000 | Rating: N/A | Image: https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/70/0340032/1.jpg?6084
# Product: Lenovo LEGION 5 GAMING 14TH GEN INTEL CORE I7 5.2GHZ 16GB RAM 1TB SSSD RTX 4060 (8GB) 16"WQXGA WINS 11 | Price: ₦ 2,940,000 | Rating: N/A | Image: https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/14/7437104/1.jpg?7324
# Product: Hp VICTUS GAMING 15 13TH GEN INTEL CORE I7 8GB RAM 1TB SSD GTX 3050 (6GB) WINS 11 | Price: ₦ 2,180,500 | Rating: N/A | Image: https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/61/7350032/1.jpg?6068
# Product: Asus VIVOBOOK PRO 16X GAMING INTEL CORE I7 16GB RAM 512GB SSD 16"4K OLED RTX 3050 (4GB) WINDOWS 11 | Price: ₦ 1,650,000 | Rating: N/A | Image: https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/99/6655104/1.jpg?8374
# Product: Hp VICTUS GAMING 15 (2022) INTEL CORE I5 16GB RAM 512GB SSD 4GB NVIDIA RTX 3050 WINS 11 | Price: ₦ 1,340,800 | Rating: N/A | Image: https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/24/9094913/1.jpg?5846
# Product: Hp VICTUS GAMING 15 13TH GEN INTEL CORE I7 16GB RAM 1TB SSD RTX 3050 (6GB) 15.6"FHD BACKLIT KEY WIN 11 | Price: ₦ 2,095,000 | Rating: N/A | Image: https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/09/5747573/1.jpg?0350
# Product: Hp VICTUS GAMING 15 13TH GEN INTEL CORE I7 16GB RAM 1TB SSD RTX 3050 (6GB) 15.6"FHD BACKLIT KEY WIN 11 | Price: ₦ 1,990,000 | Rating: N/A | Image: https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/05/8811573/1.jpg?1989
# Product: Msi Titan 18 Gaming Laptop ( HX A14VIG-088US) Intel Core I9-14900HX | Price: ₦ 9,500,000 | Rating: N/A | Image: https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/59/4448404/1.jpg?2168
# ✅ Data saved to jumia_products.csv

# %%
import asyncio
import pandas as pd
from itertools import zip_longest
from playwright.async_api import async_playwright

async def scrape_jumia():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)  # Run in headless mode
        page = await browser.new_page()

        all_products = []  # Store all products

        for page_number in range(1,5):  # Scrape pages 1 to 10
            url = f"https://www.jumia.com.ng/gaming-laptops/?page={page_number}"
            print(f"Scraping: {url}")
            await page.goto(url)

            # Wait for products to load
            await page.wait_for_selector(".name", timeout=60000) 

            # Extract product names
            product_names = await page.locator(".name").all_inner_texts()

            # Extract prices
            product_prices = await page.locator(".prc").all_inner_texts()

            # Extract ratings
            product_rating = await page.locator(".rev").all_inner_texts()

            # Extract image URLs
            product_images = await page.locator(".img").evaluate_all("elements => elements.map(e => e.getAttribute('data-src'))")

            # Ensure all lists have the same length
            aligned_data = list(zip_longest(product_names, product_prices, product_rating, product_images, fillvalue="N/A"))

            # Add products from this page to the list
            all_products.extend(aligned_data)

        # Save to CSV
        df = pd.DataFrame(all_products, columns=["Product Name", "Price", "Rating", "Image URL"])
        df.to_csv("jumia_products.csv", index=False)
        print("Data saved to jumia_products.csv")

        await browser.close()

# Run the scraper
await scrape_jumia()
# Out:
# Scraping: https://www.jumia.com.ng/gaming-laptops/?page=1
# Scraping: https://www.jumia.com.ng/gaming-laptops/?page=2
# Scraping: https://www.jumia.com.ng/gaming-laptops/?page=3
# Scraping: https://www.jumia.com.ng/gaming-laptops/?page=4
# Data saved to jumia_products.csv

# %%
product = pd.read_csv("jumia_products.csv")
product.head(20)
# Out:
#                                          Product Name        Price  \
# 0                   Lenovo Legion Pro 5 16IRX9 Gaming  ₦ 4,000,000
# 1   Hp 15 VICTUS GAMING, 12TH GEN INTEL CORE I5, 1...  ₦ 1,340,000
# 2   Anti Blue Ray Light Blocking Glasses For Compu...      ₦ 4,199
# 3   Lenovo Legion 7i - 16.0" WQXGA Display - 32GB ...  ₦ 4,000,000
# 4   Hp OMEN TRANSCEND 14 14TH GEN INTEL CORE ULTRA...  ₦ 3,999,999
# 5   Hp Omen 16 Gaming 13th Gen Intel Core I7 16GB ...  ₦ 2,500,000
# 6   Hp TUFF DASH GAMING 15 AMD RYZEN 7-7435HS 16GB...  ₦ 1,840,000
# 7   DELL Alienware M16 R2 - 16.0" QHD IPS Display ...  ₦ 3,899,000
# 8   Asus VIVOBOOK PRO 16X GAMING INTEL CORE I7 16G...  ₦ 1,650,000
# 9   Alienware x16 GAMING 13TH GEN INTEL CORE I7 UP...  ₦ 4,000,000
# 10  Hp 15 VICTUS GAMING, 12TH GEN INTEL CORE I5, 1...  ₦ 1,341,800
# 11                        Msi KATANA 15-B13VEK Gaming  ₦ 2,000,000
# 12  Hp ENVY 17-CW0097NR, 13th Gen I7,1TB/32GB RTX ...  ₦ 1,980,000
# 13  Asus VIVOBOOK PRO 15 GAMING INTEL CORE I5 8GB ...    ₦ 989,000
# 14  Alienware M17 R5 GAMING AMD RYZEN 9-6900HX UP ...  ₦ 3,900,000
# 15  Asus TUFF DASH GAMING 15 AMD RYZEN 7-7435HS 16...  ₦ 1,840,000
# 16  DELL G7630 GAMING 13TH GEN INTEL CORE I9 UP TO...  ₦ 2,952,000
# 17  Asus TUF 15 Gaming Laptop - 32GB RAM - 1TB SSD...  ₦ 3,100,000
# 18  Hp OMEN TRANSCEND 14 14TH GEN INTEL CORE ULTRA...  ₦ 3,202,000
# 19  Hp ProBook 11 X360- TOUCH- 256GB SSD/4GB RAM +...    ₦ 500,000
#
#                Rating                                          Image URL
# 0   4.4 out of 5\n(9)  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 1   3.8 out of 5\n(5)  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 2     5 out of 5\n(2)  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 3   3.3 out of 5\n(4)  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 4     5 out of 5\n(1)  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 5     5 out of 5\n(1)  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 6   4.3 out of 5\n(7)  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 7     5 out of 5\n(2)  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 8                 NaN  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 9                 NaN  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 10                NaN  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 11                NaN  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 12                NaN  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 13                NaN  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 14                NaN  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 15                NaN  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 16                NaN  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 17                NaN  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 18                NaN  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 19                NaN  https://ng.jumia.is/unsafe/fit-in/300x300/filt...
